# %% [markdown]
# # Socionics Research - Getting Started
#
# This notebook provides a starting point for working with the socionics research platform.
#
# ## Setup
#
# Make sure you've installed all dependencies:
# ```bash
# pip install -r requirements.txt
# ```

# %%
# Import the package
from src.socionics_research import hello

# Test basic functionality
print(hello("notebook user"))

# %% [markdown]
# ## Next Steps
#
# 1. Explore the database schema
# 2. Set up LLM clients
# 3. Run example analyses
# 4. Visualize results
